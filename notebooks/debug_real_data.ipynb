# %%
import pandas as pd

df = pd.read_parquet("/home/deq/project/type_n_search/data/raw/daily/daily_cache.parquet")
df.head()
# Out:
#   trade_date      open      high       low     close            vol  \
# 0 2024-01-02  8.620506  8.716897  8.562189  8.600814  309160.463372
# 1 2024-01-03  8.638916  8.691160  8.602575  8.637879  329137.767192
# 2 2024-01-04  8.620858  8.738943  8.532103  8.600568  346588.216405
# 3 2024-01-05  8.661911  8.763151  8.548997  8.627991  287815.623936
# 4 2024-01-08  8.628813  8.727585  8.477765  8.620829  302651.501359
#
#          amount   pct_chg
# 0  2.659032e+08  0.000000
# 1  2.843052e+08  0.004309
# 2  2.980855e+08 -0.004319
# 3  2.483271e+08  0.003188
# 4  2.609107e+08 -0.000830
